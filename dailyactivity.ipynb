# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\91955\Desktop\Health\dailyActivity_merged.csv")
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   04-12-2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   05-08-2016       10686       8.110000         8.110000
# 936  8877689391   05-09-2016       20226      18.250000        18.250000
# 937  8877689391   05-10-2016       10733       8.150000         8.150000
# 938  8877689391   05-11-2016       21420      19.559999        19.559999
# 939  8877689391   05-12-2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.dropna()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   04-12-2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   05-08-2016       10686       8.110000         8.110000
# 936  8877689391   05-09-2016       20226      18.250000        18.250000
# 937  8877689391   05-10-2016       10733       8.150000         8.150000
# 938  8877689391   05-11-2016       21420      19.559999        19.559999
# 939  8877689391   05-12-2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.drop_duplicates()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   04-12-2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   05-08-2016       10686       8.110000         8.110000
# 936  8877689391   05-09-2016       20226      18.250000        18.250000
# 937  8877689391   05-10-2016       10733       8.150000         8.150000
# 938  8877689391   05-11-2016       21420      19.559999        19.559999
# 939  8877689391   05-12-2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.count()
# Out:
# Id                          940
# ActivityDate                940
# TotalSteps                  940
# TotalDistance               940
# TrackerDistance             940
# LoggedActivitiesDistance    940
# VeryActiveDistance          940
# ModeratelyActiveDistance    940
# LightActiveDistance         940
# SedentaryActiveDistance     940
# VeryActiveMinutes           940
# FairlyActiveMinutes         940
# LightlyActiveMinutes        940
# SedentaryMinutes            940
# Calories                    940
# dtype: int64

# %%
#Generate basic statistics for all numeric columns(count, non missing values, min value, max value, mean, median, quartile values)

# %%
df[["Id","ActivityDate","TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","VeryActiveMinutes","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes","Calories"]].count()
# Out:
# Id                          940
# ActivityDate                940
# TotalSteps                  940
# TotalDistance               940
# TrackerDistance             940
# LoggedActivitiesDistance    940
# VeryActiveDistance          940
# ModeratelyActiveDistance    940
# LightActiveDistance         940
# SedentaryActiveDistance     940
# VeryActiveMinutes           940
# FairlyActiveMinutes         940
# LightlyActiveMinutes        940
# SedentaryMinutes            940
# Calories                    940
# dtype: int64

# %%
df[["Id","ActivityDate","TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","VeryActiveMinutes","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes","Calories"]].mean()
# Out:
# C:\Users\91955\AppData\Local\Temp\ipykernel_6628\2613547842.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[["Id","ActivityDate","TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","VeryActiveMinutes","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes","Calories"]].mean()
# Id                          4.855407e+09
# TotalSteps                  7.637911e+03
# TotalDistance               5.489702e+00
# TrackerDistance             5.475351e+00
# LoggedActivitiesDistance    1.081709e-01
# VeryActiveDistance          1.502681e+00
# ModeratelyActiveDistance    5.675426e-01
# LightActiveDistance         3.340819e+00
# ...

# %%
df["Id"].mean()
# Out:
# 4855407369.332978

# %%
df["Id"].min()
# Out:
# 1503960366

# %%
df["Id"].max()
# Out:
# 8877689391

# %%
df["Id"].median()
# Out:
# 4445114986.0

# %%
df["Id"].quantile()
# Out:
# 4445114986.0

# %%
df[["Id","ActivityDate","TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","VeryActiveMinutes","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes","Calories"]].min()
# Out:
# Id                          1503960366
# ActivityDate                04-12-2016
# TotalSteps                           0
# TotalDistance                      0.0
# TrackerDistance                    0.0
# LoggedActivitiesDistance           0.0
# VeryActiveDistance                 0.0
# ModeratelyActiveDistance           0.0
# LightActiveDistance                0.0
# SedentaryActiveDistance            0.0
# VeryActiveMinutes                    0
# FairlyActiveMinutes                  0
# LightlyActiveMinutes                 0
# SedentaryMinutes                     0
# Calories                             0
# dtype: object

# %%
df[["Id","ActivityDate","TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","VeryActiveMinutes","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes","Calories"]].max()
# Out:
# Id                          8877689391
# ActivityDate                 4/30/2016
# TotalSteps                       36019
# TotalDistance                28.030001
# TrackerDistance              28.030001
# LoggedActivitiesDistance      4.942142
# VeryActiveDistance               21.92
# ModeratelyActiveDistance          6.48
# LightActiveDistance              10.71
# SedentaryActiveDistance           0.11
# VeryActiveMinutes                  210
# FairlyActiveMinutes                143
# LightlyActiveMinutes               518
# SedentaryMinutes                  1440
# Calories                          4900
# dtype: object

# %%
df[["Id","ActivityDate","TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","VeryActiveMinutes","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes","Calories"]].median()
# Out:
# C:\Users\91955\AppData\Local\Temp\ipykernel_6628\2024848501.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[["Id","ActivityDate","TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","VeryActiveMinutes","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes","Calories"]].median()
# Id                          4.445115e+09
# TotalSteps                  7.405500e+03
# TotalDistance               5.245000e+00
# TrackerDistance             5.245000e+00
# LoggedActivitiesDistance    0.000000e+00
# VeryActiveDistance          2.100000e-01
# ModeratelyActiveDistance    2.400000e-01
# LightActiveDistance         3.365000e+00
# ...

# %%
df[["Id","ActivityDate","TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","VeryActiveMinutes","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes","Calories"]].quantile()
# Out:
# C:\Users\91955\AppData\Local\Temp\ipykernel_6628\2068560598.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[["Id","ActivityDate","TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","VeryActiveMinutes","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes","Calories"]].quantile()
# Id                          4.445115e+09
# TotalSteps                  7.405500e+03
# TotalDistance               5.245000e+00
# TrackerDistance             5.245000e+00
# LoggedActivitiesDistance    0.000000e+00
# VeryActiveDistance          2.100000e-01
# ModeratelyActiveDistance    2.400000e-01
# LightActiveDistance         3.365000e+00
# SedentaryActiveDistance     0.000000e+00
# ...
