# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\91955\Desktop\Health\dailyActivity_merged.csv")
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   04-12-2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   05-08-2016       10686       8.110000         8.110000
# 936  8877689391   05-09-2016       20226      18.250000        18.250000
# 937  8877689391   05-10-2016       10733       8.150000         8.150000
# 938  8877689391   05-11-2016       21420      19.559999        19.559999
# 939  8877689391   05-12-2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
df.dropna()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   04-12-2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   05-08-2016       10686       8.110000         8.110000
# 936  8877689391   05-09-2016       20226      18.250000        18.250000
# 937  8877689391   05-10-2016       10733       8.150000         8.150000
# 938  8877689391   05-11-2016       21420      19.559999        19.559999
# 939  8877689391   05-12-2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.drop_duplicates()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   04-12-2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   05-08-2016       10686       8.110000         8.110000
# 936  8877689391   05-09-2016       20226      18.250000        18.250000
# 937  8877689391   05-10-2016       10733       8.150000         8.150000
# 938  8877689391   05-11-2016       21420      19.559999        19.559999
# 939  8877689391   05-12-2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.count()
# Out:
# Id                          940
# ActivityDate                940
# TotalSteps                  940
# TotalDistance               940
# TrackerDistance             940
# LoggedActivitiesDistance    940
# VeryActiveDistance          940
# ModeratelyActiveDistance    940
# LightActiveDistance         940
# SedentaryActiveDistance     940
# VeryActiveMinutes           940
# FairlyActiveMinutes         940
# LightlyActiveMinutes        940
# SedentaryMinutes            940
# Calories                    940
# dtype: int64

# %%
dfn=df[["TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","Calories"]]
dfn
# Out:
#      TotalSteps  TotalDistance  TrackerDistance  LoggedActivitiesDistance  \
# 0         13162       8.500000         8.500000                       0.0
# 1         10735       6.970000         6.970000                       0.0
# 2         10460       6.740000         6.740000                       0.0
# 3          9762       6.280000         6.280000                       0.0
# 4         12669       8.160000         8.160000                       0.0
# ..          ...            ...              ...                       ...
# 935       10686       8.110000         8.110000                       0.0
# 936       20226      18.250000        18.250000                       0.0
# 937       10733       8.150000         8.150000                       0.0
# 938       21420      19.559999        19.559999                       0.0
# 939        8064       6.120000         6.120000                       0.0
#
#      VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# ...

# %%
dfc=df[["Id","ActivityDate","VeryActiveMinutes","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes"]]
dfc
# Out:
#              Id ActivityDate  VeryActiveMinutes  FairlyActiveMinutes  \
# 0    1503960366   04-12-2016                 25                   13
# 1    1503960366    4/13/2016                 21                   19
# 2    1503960366    4/14/2016                 30                   11
# 3    1503960366    4/15/2016                 29                   34
# 4    1503960366    4/16/2016                 36                   10
# ..          ...          ...                ...                  ...
# 935  8877689391   05-08-2016                 17                    4
# 936  8877689391   05-09-2016                 73                   19
# 937  8877689391   05-10-2016                 18                   11
# 938  8877689391   05-11-2016                 88                   12
# 939  8877689391   05-12-2016                 23                    1
#
#      LightlyActiveMinutes  SedentaryMinutes
# 0                     328               728
# 1                     217               776
# ...

# %%
#Generate basic statistics for all numeric columns(count, non missing values, min value, max value, mean, median, quartile values)

# %%
df[["TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","Calories"]].count()
# Out:
# TotalSteps                  940
# TotalDistance               940
# TrackerDistance             940
# LoggedActivitiesDistance    940
# VeryActiveDistance          940
# ModeratelyActiveDistance    940
# LightActiveDistance         940
# SedentaryActiveDistance     940
# Calories                    940
# dtype: int64

# %%
df[["TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","Calories"]].mean()
# Out:
# TotalSteps                  7637.910638
# TotalDistance                  5.489702
# TrackerDistance                5.475351
# LoggedActivitiesDistance       0.108171
# VeryActiveDistance             1.502681
# ModeratelyActiveDistance       0.567543
# LightActiveDistance            3.340819
# SedentaryActiveDistance        0.001606
# Calories                    2303.609574
# dtype: float64

# %%
df[["TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","Calories"]].min()
# Out:
# TotalSteps                  0.0
# TotalDistance               0.0
# TrackerDistance             0.0
# LoggedActivitiesDistance    0.0
# VeryActiveDistance          0.0
# ModeratelyActiveDistance    0.0
# LightActiveDistance         0.0
# SedentaryActiveDistance     0.0
# Calories                    0.0
# dtype: float64

# %%
df[["TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","Calories"]].max()
# Out:
# TotalSteps                  36019.000000
# TotalDistance                  28.030001
# TrackerDistance                28.030001
# LoggedActivitiesDistance        4.942142
# VeryActiveDistance             21.920000
# ModeratelyActiveDistance        6.480000
# LightActiveDistance            10.710000
# SedentaryActiveDistance         0.110000
# Calories                     4900.000000
# dtype: float64

# %%
df[["TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","Calories"]].median()
# Out:
# TotalSteps                  7405.500
# TotalDistance                  5.245
# TrackerDistance                5.245
# LoggedActivitiesDistance       0.000
# VeryActiveDistance             0.210
# ModeratelyActiveDistance       0.240
# LightActiveDistance            3.365
# SedentaryActiveDistance        0.000
# Calories                    2134.000
# dtype: float64

# %%
df[["TotalSteps","TotalDistance","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","Calories"]].quantile()
# Out:
# TotalSteps                  7405.500
# TotalDistance                  5.245
# TrackerDistance                5.245
# LoggedActivitiesDistance       0.000
# VeryActiveDistance             0.210
# ModeratelyActiveDistance       0.240
# LightActiveDistance            3.365
# SedentaryActiveDistance        0.000
# Calories                    2134.000
# Name: 0.5, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
x=["TotalSteps"]
plt.hist(x)
plt.show()

# %%
x=["TotalDistance"]
plt.hist(x)
plt.show()

# %%
x=["TrackerDistance"]
plt.hist(x)
plt.show()

# %%
x=["LoggedActivitiesDistance"]
plt.hist(x)
plt.show()

# %%
x=["VeryActiveDistance"]
plt.hist(x)
plt.show()

# %%
x=["ModeratelyActiveDistance"]
plt.hist(x)
plt.show()

# %%
x=["LightActiveDistance"]
plt.hist(x)
plt.show()

# %%
x=["SedentaryActiveDistance"]
plt.hist(x)
plt.show()

# %%
x=["Calories"]
plt.hist(x)
plt.show()

# %%
x = ["TotalDistance","TotalSteps","TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance","Calories"]
plt.hist(x)
plt.show()

# %%
import seaborn as sns
sns.countplot(data=dfc)
plt.show()

# %%
df.groupby('ActivityDate')["Calories"].count()
# Out:
# ActivityDate
# 04-12-2016    33
# 05-01-2016    30
# 05-02-2016    29
# 05-03-2016    29
# 05-04-2016    29
# 05-05-2016    29
# 05-06-2016    29
# 05-07-2016    29
# 05-08-2016    27
# 05-09-2016    27
# 05-10-2016    26
# 05-11-2016    24
# 05-12-2016    21
# 4/13/2016     33
# 4/14/2016     33
# 4/15/2016     33
# 4/16/2016     32
# 4/17/2016     32
# 4/18/2016     32
# 4/19/2016     32
# 4/20/2016     32
# 4/21/2016     32
# 4/22/2016     32
# 4/23/2016     32
# 4/24/2016     32
# 4/25/2016     32
# 4/26/2016     32
# 4/27/2016     32
# 4/28/2016     32
# 4/29/2016     32
# 4/30/2016     31
# Name: Calories, dtype: int64

# %%
df.groupby('ActivityDate')["TotalSteps"].count()
# Out:
# ActivityDate
# 04-12-2016    33
# 05-01-2016    30
# 05-02-2016    29
# 05-03-2016    29
# 05-04-2016    29
# 05-05-2016    29
# 05-06-2016    29
# 05-07-2016    29
# 05-08-2016    27
# 05-09-2016    27
# 05-10-2016    26
# 05-11-2016    24
# 05-12-2016    21
# 4/13/2016     33
# 4/14/2016     33
# 4/15/2016     33
# 4/16/2016     32
# 4/17/2016     32
# 4/18/2016     32
# 4/19/2016     32
# 4/20/2016     32
# 4/21/2016     32
# 4/22/2016     32
# 4/23/2016     32
# 4/24/2016     32
# 4/25/2016     32
# 4/26/2016     32
# 4/27/2016     32
# 4/28/2016     32
# 4/29/2016     32
# 4/30/2016     31
# Name: TotalSteps, dtype: int64
